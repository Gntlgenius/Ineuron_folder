# %%
import json
import pandas as pd
from pandas import Series, DataFrame

# %%
data = '''
{
    "subject_type": "subject",
    "name": "picture books",
    "key": "/subjects/picture_books",
    "ebook_count": 4984,
    "works": [
        {
            "printdisabled": false,
            "cover_id": 8595949,
            "ia_collection": [],
            "has_fulltext": true,
            "edition_count": 687,
            "checked_out": false,
            "title": "Alice in Wonderland!",
            "public_scan": true,
            "cover_edition_key": "OL13442629M",
            "lendinglibrary": false,
            "lending_edition": "",
            "first_publish_year": null,
            "key": "/works/OL13101191W",
            "authors": [
                {
                    "name": "Lewis Carroll",
                    "key": "/authors/OL22098A"
                }
            ],
            "ia": "aventuresdalicea00carr",
            "lending_identifier": "",
            "availability": {
                "status": "borrow_unavailable",
                "__src__": "core.models.lending.get_availability",
                "openlibrary_work": "OL151395W",
                "isbn": "0486228363",
                "is_browseable": false,
                "is_lendable": true,
                "num_waitlist": "5",
                "last_loan_date": "2020-08-18T23:24:41Z",
                "is_printdisabled": true,
                "openlibrary_edition": "OL16218706M",
                "oclc": null,
                "is_restricted": true,
                "collection": "inlibrary,printdisabled,internetarchivebooks,americana,fav-selena01018,fav-zavald,fav-gretc,fav-mermaid-in-wonderland,fav-lorawilder,cuny-ol,occidentalcollegelibrary-ol,smithsonianlibraries,stmaryscountylibrary",
                "last_waitlist_date": "2020-09-09T04:31:01Z",
                "identifier": "aventuresdalicea00carr",
                "is_readable": false
            },
            "subject": [
                "English Fantasy fiction",
                "Humor",
                "Nonsense verses",
                "Toy and movable books",
                "Criticism and interpretation",
                "Accessible book",
                "Playing cards",
                "Fiction",
                "Croquet",
                "Plays",
                "Juvenile literature",
                "Textual Criticism",
                "English Nonsense verses",
                "Picture books",
                "Fantasy in fiction",
                "Texts",
                "Specimens",
                "Anthropomorphism",
                "Children's literature",
                "English Adventure stories",
                "Alice (fictitious character : carroll), fiction",
                "Artists' illustrated books",
                "Mythical Animals",
                "English Fantasy literature",
                "Classic Literature",
                "Gregg",
                "Fantasy  Magic",
                "Animals",
                "Girls, fiction",
                "Open Library Staff Picks",
                "Children's literature, English",
                "Children's stories, English",
                "Dictionaries",
                "Fantasy & Magic",
                "Tea",
                "Books and reading",
                "Fantasy fiction, history and criticism",
                "Ficci\u00f3n juvenil",
                "Novela fant\u00e1stica",
                "English language",
                "Children's stories",
                "English",
                "Portuguese language materials",
                "Classics",
                "Alice (Fictitious character : Carroll)",
                "Children's fiction",
                "History",
                "British and irish fiction (fictional works by one author)",
                "hookahs",
                "Humorous stories",
                "Shorthand",
                "German",
                "Fantasy fiction",
                "Juvenile fiction",
                "History and criticism",
                "Fantas\u00eda",
                "Fiction, fantasy, general",
                "Imagination & Play",
                "Fantasy",
                "Fairy tales",
                "English Fantastic fiction",
                "logic",
                "literary nonsense",
                "Children"
            ]
        },
        {
            "printdisabled": false,
            "cover_id": 2668686,
            "ia_collection": [],
            "has_fulltext": true,
            "edition_count": 180,
            "checked_out": false,
            "title": "Heidi",
            "public_scan": true,
            "cover_edition_key": "OL11665757M",
            "lendinglibrary": false,
            "lending_edition": "",
            "first_publish_year": null,
            "key": "/works/OL1455042W",
            "authors": [
                {
                    "name": "Johanna Spyri",
                    "key": "/authors/OL6918335A"
                }
            ],
            "ia": "heidipocket00spyr",
            "lending_identifier": "",
            "availability": {
                "status": "borrow_unavailable",
                "__src__": "core.models.lending.get_availability",
                "openlibrary_work": "OL1455042W",
                "isbn": "0883017520",
                "is_browseable": false,
                "is_lendable": true,
                "num_waitlist": null,
                "last_loan_date": null,
                "is_printdisabled": true,
                "openlibrary_edition": "OL24209298M",
                "oclc": null,
                "is_restricted": true,
                "collection": "inlibrary,printdisabled,internetarchivebooks,americana",
                "last_waitlist_date": null,
                "identifier": "heidipocket00spyr",
                "is_readable": false
            },
            "subject": [
                "Story",
                "Babies",
                "Accessible book",
                "Grandparents, fiction",
                "Swiss (German)",
                "Kid's",
                "Book",
                "Grades 3-4",
                "e-book",
                "Invalids",
                "Literature",
                "Picture Books",
                "Nature",
                "Switzerland, fiction",
                "Toddlers",
                "5 Year old",
                "Grandfathers",
                "Fiction, general",
                "Adult",
                "Girls, fiction",
                "Braille",
                "Orphans",
                "Audio book",
                "Paperback",
                "Grandfather",
                "Children's",
                "Stories",
                "Johanna Spyri",
                "Fiction",
                "Children's fiction",
                "Love of nature",
                "History",
                "Juvenile",
                "Chapter books",
                "Family",
                "Classic",
                "Orphans, fiction",
                "Swiss Alps",
                "Juvenile fiction",
                "Orphan",
                "Goats",
                "Hardcover",
                "Heidi (fictional character)",
                "Shirley Temple",
                "Mountain life",
                "Children",
                "Movie tie-in"
            ]
        },
        {
            "printdisabled": false,
            "cover_id": 8236410,
            "ia_collection": [],
            "has_fulltext": true,
            "edition_count": 172,
            "checked_out": false,
            "title": "The Night Before Christmas",
            "public_scan": true,
            "cover_edition_key": "OL5466462M",
            "lendinglibrary": false,
            "lending_edition": "",
            "first_publish_year": null,
            "key": "/works/OL655908W",
            "authors": [
                {
                    "name": "Clement Clarke Moore",
                    "key": "/authors/OL51027A"
                }
            ],
            "ia": "visitfromstnicho00inmoor",
            "lending_identifier": "",
            "availability": {
                "status": "open",
                "__src__": "core.models.lending.get_availability",
                "openlibrary_work": "OL655908W",
                "isbn": null,
                "is_browseable": false,
                "is_lendable": false,
                "num_waitlist": null,
                "last_loan_date": null,
                "is_printdisabled": false,
                "openlibrary_edition": "OL5466462M",
                "oclc": null,
                "is_restricted": false,
                "collection": "university_pittsburgh,americana,fav-heidihob,fav-goodeve,fav-supaticha,fav-joshrocklage,fav-stlb,fav-elyaqim,fav-taprootphoto,fav-lacegl130,fav-douglas_e_welch,fav-avstock,fav-ltdean",
                "last_waitlist_date": null,
                "identifier": "visitfromstnicho00inmoor",
                "is_readable": true
            },
            "subject": [
                "American Narrative poetry",
                "Children's fiction",
                "Picture books",
                "Juvenile poetry",
                "Poetry, juvenile",
                "Glow-in-the-dark books",
                "Christmas, poetry",
                "Children's poetry",
                "Poetry",
                "Christmas poetry",
                "Santa claus, poetry",
                "Accessible book",
                "Christmas, fiction",
                "American poetry",
                "Santa in juvenile prison",
                "Narrative poetry",
                "Specimens",
                "Christmas",
                "Santa Claus",
                "Children's poetry, American"
            ]
        },
        {
            "printdisabled": false,
            "cover_id": 24078,
            "ia_collection": [],
            "has_fulltext": true,
            "edition_count": 52,
            "checked_out": false,
            "title": "Where the Wild Things Are",
            "public_scan": true,
            "cover_edition_key": "OL9231088M",
            "lendinglibrary": false,
            "lending_edition": "",
            "first_publish_year": null,
            "key": "/works/OL15638539W",
            "authors": [
                {
                    "name": "Maurice Sendak",
                    "key": "/authors/OL366346A"
                }
            ],
            "ia": "WhereTheWildThingsAre_180",
            "lending_identifier": "",
            "availability": {
                "status": "error",
                "__src__": "core.models.lending.get_availability",
                "is_lendable": false,
                "error_message": "not found",
                "is_browseable": false,
                "is_printdisabled": false,
                "is_restricted": true,
                "identifier": "WhereTheWildThingsAre_180",
                "is_readable": false
            },
            "subject": [
                "Conduct of life",
                "Picture books",
                "Spanish language materials",
                "Fiction",
                "Miniature books",
                "Specimens",
                "Monsters",
                "Kings and rulers",
                "Imagination",
                "Accelerated Reader 2.9.",
                "Caldecott Medal",
                "Accessible book",
                "Dreams",
                "Novela",
                "Fantasty",
                "Animals",
                "Fantas\u00eda",
                "Ficci\u00f3n juvenil",
                "open_syllabus_project",
                "Monsters, fiction",
                "Children's fiction",
                "Fantasy fiction",
                "Juvenile fiction",
                "Fantasy",
                "Fairy tales",
                "Monstruos",
                "Caldecott Medal books",
                "Children",
                "Temper tantrums"
            ]
        },
        {
            "printdisabled": false,
            "cover_id": 50749,
            "ia_collection": [],
            "has_fulltext": true,
            "edition_count": 39,
            "checked_out": false,
            "title": "Goodnight moon",
            "public_scan": true,
            "cover_edition_key": "OL9246679M",
            "lendinglibrary": false,
            "lending_edition": "",
            "first_publish_year": null,
            "key": "/works/OL151887W",
            "authors": [
                {
                    "name": "Margaret Wise Brown",
                    "key": "/authors/OL22122A"
                }
            ],
            "ia": "buenasnochesluna00brow",
            "lending_identifier": "",
            "availability": {
                "status": "borrow_unavailable",
                "__src__": "core.models.lending.get_availability",
                "openlibrary_work": "OL151887W",
                "isbn": "9686394028",
                "is_browseable": false,
                "is_lendable": true,
                "num_waitlist": "0",
                "last_loan_date": "2020-09-04T12:25:37Z",
                "is_printdisabled": true,
                "openlibrary_edition": "OL22900725M",
                "oclc": null,
                "is_restricted": true,
                "collection": "inlibrary,printdisabled,internetarchivebooks,delawarecountydistrictlibrary,americana,fav-yoy0zoo,fav-etsfairview,bpljordan-ol,cnusd-ol,cuny-ol,library_of_atlantis,stmaryscountylibrary",
                "last_waitlist_date": "2020-01-18T22:04:31Z",
                "identifier": "buenasnochesluna00brow",
                "is_readable": false
            },
            "subject": [
                "Night, fiction",
                "Picture books",
                "Hmong language materials",
                "Spanish language materials",
                "Concepts",
                "Fiction",
                "Rabbits in fiction",
                "Bilingual",
                "Specimens",
                "JUVENILE FICTION",
                "Counting books",
                "Bedtime in fiction",
                "Words",
                "Conejos",
                "Bedtime, fiction",
                "Picture books for children",
                "Accessible book",
                "Rabbits, fiction",
                "Moon, fiction",
                "Stories in rhyme",
                "Ficci\u00f3n juvenil",
                "Night",
                "Classics",
                "Children's fiction",
                "Rabbits",
                "Juvenile fiction",
                "Bedtime & Dreams",
                "Board books",
                "Hora de acostarse",
                "Sleep",
                "Bedtime",
                "Moon in fiction",
                "Libros de l\u00e1minas"
            ]
        },
        {
            "printdisabled": false,
            "cover_id": 259533,
            "ia_collection": [],
            "has_fulltext": false,
            "edition_count": 36,
            "checked_out": false,
            "title": "The selfish giant",
            "public_scan": false,
            "cover_edition_key": "OL1402428M",
            "lendinglibrary": false,
            "lending_edition": "",
            "first_publish_year": null,
            "key": "/works/OL14877873W",
            "authors": [
                {
                    "name": "Oscar Wilde",
                    "key": "/authors/OL20646A"
                }
            ],
            "ia": null,
            "lending_identifier": "",
            "subject": [
                "Giants",
                "Juvenile fiction",
                "Fairy tales",
                "Picture books",
                "Fiction"
            ]
        },
        {
            "printdisabled": false,
            "cover_id": 3177892,
            "ia_collection": [],
            "has_fulltext": true,
            "edition_count": 31,
            "checked_out": false,
            "title": "A Bell for Ursli",
            "public_scan": true,
            "cover_edition_key": "OL12681428M",
            "lendinglibrary": false,
            "lending_edition": "",
            "first_publish_year": null,
            "key": "/works/OL9058180W",
            "authors": [
                {
                    "name": "Selina Ch\u00f6nz",
                    "key": "/authors/OL3168520A"
                },
                {
                    "name": "Alois Carigiet",
                    "key": "/authors/OL1363298A"
                }
            ],
            "ia": "bellforursli0000chon",
            "lending_identifier": "",
            "availability": {
                "status": "borrow_unavailable",
                "__src__": "core.models.lending.get_availability",
                "openlibrary_work": "OL9058180W",
                "isbn": null,
                "is_browseable": false,
                "is_lendable": true,
                "num_waitlist": null,
                "last_loan_date": null,
                "is_printdisabled": true,
                "openlibrary_edition": "OL24399408M",
                "oclc": null,
                "is_restricted": true,
                "collection": "inlibrary,printdisabled,internetarchivebooks",
                "last_waitlist_date": null,
                "identifier": "bellforursli0000chon",
                "is_readable": false
            },
            "subject": [
                "Translations of Rhaeto-Romance/Romansh texts",
                "Accessible book",
                "Poetry",
                "Children",
                "Picture books"
            ]
        },
        {
            "printdisabled": false,
            "cover_id": 4985653,
            "ia_collection": [],
            "has_fulltext": true,
            "edition_count": 31,
            "checked_out": false,
            "title": "Green Eggs and Ham",
            "public_scan": true,
            "cover_edition_key": "OL9535182M",
            "lendinglibrary": false,
            "lending_edition": "",
            "first_publish_year": null,
            "key": "/works/OL1898308W",
            "authors": [
                {
                    "name": "Dr. Seuss",
                    "key": "/authors/OL2622837A"
                }
            ],
            "ia": "greeneggshamwith00seus",
            "lending_identifier": "",
            "availability": {
                "status": "borrow_unavailable",
                "__src__": "core.models.lending.get_availability",
                "openlibrary_work": "OL1898308W",
                "isbn": "9780375810886",
                "is_browseable": false,
                "is_lendable": true,
                "num_waitlist": "4",
                "last_loan_date": "2020-08-25T17:01:04Z",
                "is_printdisabled": true,
                "openlibrary_edition": "OL22142271M",
                "oclc": null,
                "is_restricted": true,
                "collection": "inlibrary,printdisabled,internetarchivebooks,china,fav-brisec,fav-user_15576,cnusd-ol",
                "last_waitlist_date": "2020-09-08T02:11:38Z",
                "identifier": "greeneggshamwith00seus",
                "is_readable": false
            },
            "subject": [
                "Ham",
                "Green Eggs and Ham",
                "Accessible book",
                "Beginner Books",
                "Fiction",
                "Food habits",
                "Specimens",
                "Picture books",
                "In rhymes",
                "2-3 years",
                "Food",
                "Eggs",
                "Dr. Seuss",
                "Food, fiction",
                "1960-1988",
                "Large type books",
                "Audio-Cassette included",
                "Open Library Staff Picks",
                "Juvenile Fiction",
                "Children's",
                "Humorous stories",
                "Stories",
                "Nonsense verses",
                "English",
                "Children's fiction",
                "Rhyming",
                "I Can Read It All By Myself",
                "First time readers",
                "Books",
                "Stories in rhyme",
                "Pre-school"
            ]
        },
        {
            "printdisabled": false,
            "cover_id": 401178,
            "ia_collection": [],
            "has_fulltext": true,
            "edition_count": 28,
            "checked_out": false,
            "title": "Make Way for Ducklings",
            "public_scan": true,
            "cover_edition_key": "OL7642163M",
            "lendinglibrary": false,
            "lending_edition": "",
            "first_publish_year": null,
            "key": "/works/OL4638388W",
            "authors": [
                {
                    "name": "Robert McCloskey",
                    "key": "/authors/OL952410A"
                }
            ],
            "ia": "makewayforduckl000mccl",
            "lending_identifier": "",
            "availability": {
                "status": "borrow_available",
                "__src__": "core.models.lending.get_availability",
                "openlibrary_work": "OL4638388W",
                "isbn": "9780140501711",
                "is_browseable": false,
                "is_lendable": true,
                "num_waitlist": "0",
                "last_loan_date": "2020-09-06T02:07:57Z",
                "is_printdisabled": true,
                "openlibrary_edition": "OL18658157M",
                "oclc": null,
                "is_restricted": true,
                "collection": "inlibrary,printdisabled,internetarchivebooks,delawarecountydistrictlibrary,china,americana,fav-blackbetty85,fav-gonzalja,fav-daniela_m_brown,fav-rp76,fav-skbjr,fav-walter-fam,belmont-ol,cnusd-ol,cuny-ol,holdings-test,library_of_atlantis,randolph-macon-college-ol,stmaryscountylibrary,worthingtonlibraries-ol",
                "last_waitlist_date": "2019-09-09T16:36:39Z",
                "identifier": "makewayforduckl000mccl",
                "is_readable": false
            },
            "subject": [
                "Oversize books",
                "Picture books",
                "Accessible book",
                "Fiction",
                "ducklings",
                "3.1.",
                "Specimens",
                "Accelerated Reader",
                "Japanese language books",
                "Caldecott Medal",
                "Boston (mass.), fiction",
                "Picture books for children",
                "Caldecott medal book",
                "Animals",
                "Braille",
                "illustration",
                "Ducks, Geese",
                "Books and reading",
                "Children's stories",
                "Classics",
                "Children's fiction",
                "Blind",
                "Family",
                "Juvenile fiction",
                "Ducks, fiction",
                "Ducks",
                "Big books",
                "kid's books",
                "Caldecott Medal books",
                "Accelerated Reader - 3.1."
            ]
        },
        {
            "printdisabled": false,
            "cover_id": 458091,
            "ia_collection": [],
            "has_fulltext": true,
            "edition_count": 27,
            "checked_out": false,
            "title": "The snowman",
            "public_scan": true,
            "cover_edition_key": "OL7862216M",
            "lendinglibrary": false,
            "lending_edition": "",
            "first_publish_year": null,
            "key": "/works/OL15845200W",
            "authors": [
                {
                    "name": "Raymond Briggs",
                    "key": "/authors/OL27042A"
                }
            ],
            "ia": "snowman00brig_0",
            "lending_identifier": "",
            "availability": {
                "status": "borrow_available",
                "__src__": "core.models.lending.get_availability",
                "openlibrary_work": "OL462838W",
                "isbn": "9780679888963",
                "is_browseable": false,
                "is_lendable": true,
                "num_waitlist": "0",
                "last_loan_date": "2020-09-05T08:46:14Z",
                "is_printdisabled": true,
                "openlibrary_edition": "OL711144M",
                "oclc": null,
                "is_restricted": true,
                "collection": "inlibrary,printdisabled,internetarchivebooks,china,fav-kemble_flynn,bpljordan-ol,goffstownlibrary-ol,stmaryscountylibrary",
                "last_waitlist_date": "2019-11-17T01:41:39Z",
                "identifier": "snowman00brig_0",
                "is_readable": false
            },
            "subject": [
                "Picture books",
                "Toy and movable books",
                "Readers",
                "Accessible book",
                "Fiction",
                "Miniature books",
                "Specimens",
                "Stories without words",
                "Problems, exercises",
                "Vocabulary",
                "Juvenile literature",
                "JUVENILE FICTION",
                "Social Themes",
                "Study and teaching",
                "Picture books for children",
                "Dreams",
                "Cartoons and caricatures",
                "Comics & Graphic Novels",
                "English language",
                "Cartoons and comics",
                "Friendship",
                "Juvenile fiction",
                "Bedtime & Dreams",
                "General",
                "Study and teaching (Primary)",
                "Welsh language",
                "Snowmen"
            ]
        },
        {
            "printdisabled": false,
            "cover_id": 254689,
            "ia_collection": [],
            "has_fulltext": true,
            "edition_count": 27,
            "checked_out": false,
            "title": "Frederick",
            "public_scan": true,
            "cover_edition_key": "OL5289758M",
            "lendinglibrary": false,
            "lending_edition": "",
            "first_publish_year": null,
            "key": "/works/OL2162573W",
            "authors": [
                {
                    "name": "Leo Lionni (1910-1999)",
                    "key": "/authors/OL7629993A"
                }
            ],
            "ia": "frederick00leol",
            "lending_identifier": "",
            "availability": {
                "status": "borrow_unavailable",
                "__src__": "core.models.lending.get_availability",
                "openlibrary_work": "OL2162573W",
                "isbn": "0590979396",
                "is_browseable": false,
                "is_lendable": true,
                "num_waitlist": null,
                "last_loan_date": null,
                "is_printdisabled": true,
                "openlibrary_edition": "OL15349784M",
                "oclc": null,
                "is_restricted": true,
                "collection": "inlibrary,printdisabled,internetarchivebooks,delawarecountydistrictlibrary,china,americana,fav-bluish_green,fav-in2artlife,fav-sureamama,fav-warmwarm,fav-danidelpico,fav-feathers92,fav-oatmlcookie,fav-elovfald,holdings-test,library_of_atlantis,phillipsacademy-preview,smithsonianlibraries,stmaryscountylibrary",
                "last_waitlist_date": null,
                "identifier": "frederick00leol",
                "is_readable": false
            },
            "subject": [
                "Mice in fiction",
                "Sharing",
                "Families",
                "Winter",
                "Accelerated Reader 3.5.",
                "Juvenile fiction",
                "Fiction",
                "Imagination",
                "Accessible book",
                "Fairy tales",
                "Fiction, general",
                "Children's stories",
                "Mice",
                "Children's fiction",
                "Picture books"
            ]
        },
        {
            "printdisabled": false,
            "cover_id": 14324,
            "ia_collection": [],
            "has_fulltext": true,
            "edition_count": 25,
            "checked_out": false,
            "title": "Rosie's walk",
            "public_scan": true,
            "cover_edition_key": "OL9219816M",
            "lendinglibrary": false,
            "lending_edition": "",
            "first_publish_year": null,
            "key": "/works/OL18805W",
            "authors": [
                {
                    "name": "Pat Hutchins",
                    "key": "/authors/OL24290A"
                }
            ],
            "ia": "rosieswalk00hutc",
            "lending_identifier": "",
            "availability": {
                "status": "borrow_unavailable",
                "__src__": "core.models.lending.get_availability",
                "openlibrary_work": "OL18805W",
                "isbn": "0020437501",
                "is_browseable": false,
                "is_lendable": true,
                "num_waitlist": "2",
                "last_loan_date": "2020-09-07T02:13:54Z",
                "is_printdisabled": true,
                "openlibrary_edition": "OL9219816M",
                "oclc": null,
                "is_restricted": true,
                "collection": "inlibrary,printdisabled,internetarchivebooks,china,fav-rachaelmurphy,fav-kateoc,fav-kcdavies,fav-neko7,cnusd-ol,stmaryscountylibrary",
                "last_waitlist_date": "2020-09-09T01:29:23Z",
                "identifier": "rosieswalk00hutc",
                "is_readable": false
            },
            "subject": [
                "Picture books",
                "Hunting",
                "Escapes",
                "Juvenile fiction",
                "Chickens",
                "Foxes",
                "Fiction",
                "Chinese language materials",
                "Accessible book",
                "Juvenile Wit and humor",
                "Domestic animals",
                "Spanish language materials"
            ]
        }
    ],
    "work_count": 4984
}

'''

# %%
data = json.loads(data)
#data = json.dumps(data)
#     for each in Author:
#         print(each['name'])

# %%
try:
    for record in data['works']:

        #Author=record['authors']
        Availability = record['availability']
        if Availability:
                print(Availability['status'])
        else:
                print('none')
        continue
except:
    print('error in json arrangement')
# Out:
# borrow_unavailable
# borrow_unavailable
# open
# error
# borrow_unavailable
# error in json arrangement

# %%
for items in details:
    print(items['printdisabled'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-f124d6f88615> in <module>
#       1 for items in details:
# ----> 2     print(items['printdisabled'])
#
# TypeError: string indices must be integers
